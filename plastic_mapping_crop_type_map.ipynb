# %% [markdown]
# ## Mapped crop types
# ['Oranges',
#  'Pistachios',
#  'Wheat',
#  'Lemons',
#  'Walnuts',
#  'Almonds',
#  'Sunflowers',
#  'Olives',
#  'Avocados',
#  'Prunes',
#  'Strawberries']
