# %% [markdown]
# ### Monitored crop types

# %%
# Out:
# ['Almonds (drip tape)', 'Avocados (drip tape)', 'Lemons (drip tape)', 'Olives (drip tape)', 'Oranges (drip tape)', 'Pistachios (drip tape)', 'Prunes (drip tape)', 'Strawberries (drip tape)', 'Strawberries (mulch)', 'Sunflowers (drip tape)', 'Walnuts (drip tape)', 'Wheat (drip tape)']

# %% [markdown]
# ## Map: county-level

# %%
# add up plastic usage for each crop type

# %% [markdown]
# ## Map: state-level

# %%
# add up plastic weight based on plastic category per county

# %%
# add up total plastic weight based on plastic category per county
